# %%
import pandas as pd

# %%
dataset = pd.read_json("../dataset/memes.json")
dataset
# Out:
#     id                     name                          base_img  width  \
# 0    0      Drake Hotline Bling  https://i.imgflip.com/30b1gx.jpg   1200
# 1    1     Distracted Boyfriend  https://i.imgflip.com/1ur9b0.jpg   1200
# 2    2              Two Buttons  https://i.imgflip.com/1g8my4.jpg    600
# 3    3           Change My Mind  https://i.imgflip.com/24y43o.jpg    482
# 4    4        Mocking Spongebob  https://i.imgflip.com/1otk96.jpg    502
# ..  ..                      ...                               ...    ...
# 76  94       Marvel Civil War 1   https://i.imgflip.com/govs4.jpg    423
# 77  95            Philosoraptor    https://i.imgflip.com/1bgs.jpg    500
# 78  96          Me And The Boys  https://i.imgflip.com/320xfw.jpg    720
# 79  98  I Should Buy A Boat Cat    https://i.imgflip.com/tau4.jpg    500
# 80  99          Sparta Leonidas    https://i.imgflip.com/46rh.jpg    500
#
#     height  text_box                                    generated_memes
# ...
